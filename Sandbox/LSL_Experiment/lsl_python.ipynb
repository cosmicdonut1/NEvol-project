# %%
import sys
from pylsl import StreamInlet, resolve_stream
import random
import time
import signal

# %%
# Resolve LSL stream
print("Looking for an EEG stream...")
streams = resolve_stream("name", "UN-2023.04.61")
# Out:
# Looking for an EEG stream...

# %%
stream_inlet = StreamInlet(streams[0])

# %%
def signal_handler(signal, frame):
    print("\nCtrl+C detected. Exiting gracefully...")
    exit()

# %%
# Register signal handler for Ctrl+C
signal.signal(signal.SIGINT, signal_handler)

try:
    while True:
        # Get a new sample (you can also omit the timestamp part if you're not interested in it)
        sample, timestamp = stream_inlet.pull_sample()
        print(sample)
except KeyboardInterrupt:
    print("\nCtrl+C detected. Exiting gracefully...")
# Out:
# 551396.7084827 [750000.0625, 568217.3125, 741916.1875, 750000.0625, 711751.1875, 664835.0625, 750000.0625, 727843.75, -0.029052734375, 0.98681640625, -0.038818359375, 0.0, 0.0, 0.0, 60.0, 1.0, 1.0]
# 551396.7101919 [543771.1875, 69945.140625, 354107.15625, 604023.1875, 479369.125, 418608.125, 654154.3125, 413446.59375, -0.03662109375, 0.999755859375, -0.044189453125, 0.0, 0.0, 0.0, 60.0, 2.0, 1.0]
# 551396.7128301 [471068.59375, -10699.4228515625, 272554.875, 586514.1875, 445196.0625, 384491.25, 547694.9375, 374502.875, -0.037841796875, 1.00537109375, -0.048095703125, 0.0, 0.0, 0.0, 60.0, 3.0, 1.0]
# 551396.7163755 [538874.3125, 59685.95703125, 289770.34375, 620272.5625, 477506.40625, 399231.3125, 676027.375, 400162.0625, -0.03564453125, 1.00634765625, -0.048095703125, 0.0, 0.0, 0.0, 60.0, 4.0, 1.0]
# ...

# %%
# first create a new stream info (here we set the name to BioSemi, the content-
joul# The last value would be the serial number of the device or some other more or
Irecover).
Jinfo = pyls1.stream_info('BioSemi, 'EEG',8,100,pylsl.cf_float32,'dsffwerwer");
1
j= next make an outlet
outlet = pylsl.stream_outlet(info)
print("now sending data ... ")
nwhile True:
# make a new random 8-channel sample; this is converted into a pylsl.ve
mysample = pylsl.vectorf([random.random(),random.random(),random.randor
# now send it and wait for a bit
outlet.push_sample(mysarple)
time.sleep(0.01)N ...

Providing Data to LSL

instantiate the library
lilimport sys; sys.path. append(' .. ") # make sure that pylsl is found (note: in a l
jimport pyls1
import random
Is timport time
# first create a new stream info (here we set the name to BioSemi, the content-
joul# The last value would be the serial number of the device or some other more or
Irecover).
Jinfo = pyls1.stream_info('BioSemi, 'EEG',8,100,pylsl.cf_float32,'dsffwerwer");
1
j= next make an outlet
outlet = pylsl.stream_outlet(info)
print("now sending data ... ")
nwhile True:
# make a new random 8-channel sample; this is converted into a pylsl.ve
mysample = pylsl.vectorf([random.random(),random.random(),random.randor
# now send it and wait for a bit
outlet.push_sample(mysarple)
time.sleep(0.01)lilimport sys; sys.path. append(' .. ") # make sure that pylsl is found (note: in a l
jimport pyls1
import random
Is timport time
# first create a new stream info (here we set the name to BioSemi, the content-
joul# The last value would be the serial number of the device or some other more or
Irecover).
Jinfo = pyls1.stream_info('BioSemi, 'EEG',8,100,pylsl.cf_float32,'dsffwerwer");
1
j= next make an outlet
outlet = pylsl.stream_outlet(info)
print("now sending data ... ")
nwhile True:
# make a new random 8-channel sample; this is converted into a pylsl.ve
mysample = pylsl.vectorf([random.random(),random.random(),random.randor
# now send it and wait for a bit
outlet.push_sample(mysarple)
time.sleep(0.01)
